# %% [markdown]
# # Starting out with Dimensions #

# %% [markdown]
# Dimcli is a Python client for accessing the Dimensions API, which helps authenticate into the API and handle query requests/responses.

# %%
# necessary imports
import dimcli
import pandas as pd
import networkx as nx

# visualization libraries
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# visualization settings
sns.set_style("white")
sns.set(rc={'figure.figsize':(12, 10)})

# %%
# get access with config file. resource: https://digital-science.github.io/dimcli/getting-started.html# 
dimcli.login()
# Out:
# Searching config file credentials for default 'live' instance..
# Dimcli - Dimensions API Client (v1.2)
# Connected to: <https://app.dimensions.ai/api/dsl> - DSL v2.9
# Method: dsl.ini file

# %%
dsl = dimcli.Dsl()

# %% [markdown]
# # An Overview of Using Dimcli to Access Dimensions Data

# %% [markdown]
# One way to query data is using the dimcli instance to make requests.

# %%
dsl.query("search publications for \"malaria\" return publications limit 1").data # use data attribute to get JSON of info
# Out:
# Returned Publications: 1 (total = 1040738)
# Time: 1.69s
# WARNINGS [1]
# Field current_organization_id of the authors field is deprecated and will be removed in the next major release.
# {'_copyright': '© 2024 Digital Science & Research Solutions Inc. All rights reserved. Please refer to our Copyright Notice https://terms.dsrsi.com/public/DimensionsCopyrightNotice for further information.',
#  '_stats': {'limit': 1, 'offset': 0, 'total_count': 1040738},
#  '_version': {'release': '2.9', 'version': '2.9.1'},
#  '_warnings': ['Field current_organization_id of the authors field is deprecated and will be removed in the next major release.'],
#  'publications': [{'authors': [{'affiliations': [{'city': 'Bangkok',
#        'city_id': 1609350,
#        'country': 'Thailand',
#        'country_code': 'TH',
#        'id': 'grid.501272.3',
#        'name': 'Mahidol Oxford Tropical Medicine Research Unit',
#        'raw_affiliation': 'Mahidol Oxford Research Unit, Faculty of Tropical Medicine, Mahidol University, Bangkok, Thailand',
#        'state': None,
#        'state_code': None},
#       {'city': 'Oxford',
#        'city_id': 2640729,
#        'country': 'United Kingdom',
#        'country_code': 'GB',
#        'id': 'grid.4991.5',
#        'name': 'University of Oxford',
#        'raw_affiliation': 'Centre for Tropical Medicine and Global Health, Nuffield Department of Medicine, University of Oxford, Oxford, UK',
#        'state': None,
#        'state_code': None}],
#      'corresponding': True,
#      'current_organization_id': 'grid.4991.5',
#      'first_name': 'Nicholas J.',
#      'last_name': 'White',
#      'orcid': ['0000-0002-1897-1978'],
#      'raw_affiliation': ['Mahidol Oxford Research Unit, Faculty of Tropical Medicine, Mahidol University, Bangkok, Thailand',
#       'Centre for Tropical Medicine and Global Health, Nuffield Department of Medicine, University of Oxford, Oxford, UK'],
#      'researcher_id': 'ur.01332073522.49'}],
#    'id': 'pub.1151600368',
#    'issue': '1',
#    'journal': {'id': 'jour.1030597', 'title': 'Malaria Journal'},
#    'pages': '284',
#    'title': 'Severe malaria',
#    'type': 'article',
#    'volume': '21',
#    'year': 2022}]}

# %% [markdown]
# Another way to query information is to use Dimcli magic commands, created specifically for the Jupyter environment, that run faster. This specific command returns a pandas dataframe.

# %%
# %%dsldf
#
# search publications
#     for "malaria"
# return publications [title + research_orgs + research_org_names + times_cited + funders]
# limit 5
# Out:
# Returned Publications: 5 (total = 1040738)
# Time: 0.67s
#                                                title  \
# 0                                     Severe malaria
# 1  Malaria control and elimination in Kenya: econ...
# 2  Automated measurement of malaria parasitaemia ...
# 3  Leveraging geo-referenced malaria information ...
# 4  Establishing and applying an adaptive strategy...
#
#                                              funders  \
# 0  [{'acronym': 'WT', 'city_name': 'London', 'cou...
# 1  [{'acronym': 'DFG', 'city_name': 'Bonn', 'coun...
# 2                                                NaN
# 3  [{'acronym': 'WHO', 'city_name': 'Geneva', 'co...
# 4  [{'acronym': 'NSFC', 'city_name': 'Beijing', '...
#
#                                   research_org_names  \
# 0  [Mahidol Oxford Tropical Medicine Research Uni...
# 1  [International Food Policy Research Institute,...
# 2  [Sysmex (Germany), Malawi Blood Transfusion Se...
# 3  [World Health Organization, Nonthaburi, Thaila...
# 4        [National Institute for Parasitic Diseases]
#
#                                        research_orgs  times_cited
# 0  [{'acronym': 'MORU', 'city_name': 'Bangkok', '...           32
# 1  [{'acronym': 'ARC', 'city_name': 'Wad Medani',...            2
# 2  [{'acronym': 'MBTS', 'city_name': 'Blantyre', ...            0
# 3  [{'city_name': 'Nonthaburi', 'country_code': '...            3
# 4  [{'acronym': 'NIPD', 'city_name': 'Shanghai', ...           13

# %%
# all magic commands result stored in..
dsl_last_results.head()
# Out:
#                                                title  \
# 0                                     Severe malaria
# 1  Malaria control and elimination in Kenya: econ...
# 2  Automated measurement of malaria parasitaemia ...
# 3  Leveraging geo-referenced malaria information ...
# 4  Establishing and applying an adaptive strategy...
#
#                                              funders  \
# 0  [{'acronym': 'WT', 'city_name': 'London', 'cou...
# 1  [{'acronym': 'DFG', 'city_name': 'Bonn', 'coun...
# 2                                                NaN
# 3  [{'acronym': 'WHO', 'city_name': 'Geneva', 'co...
# 4  [{'acronym': 'NSFC', 'city_name': 'Beijing', '...
#
#                                   research_org_names  \
# 0  [Mahidol Oxford Tropical Medicine Research Uni...
# 1  [International Food Policy Research Institute,...
# 2  [Sysmex (Germany), Malawi Blood Transfusion Se...
# 3  [World Health Organization, Nonthaburi, Thaila...
# 4        [National Institute for Parasitic Diseases]
#
#                                        research_orgs  times_cited
# 0  [{'acronym': 'MORU', 'city_name': 'Bangkok', '...           32
# 1  [{'acronym': 'ARC', 'city_name': 'Wad Medani',...            2
# 2  [{'acronym': 'MBTS', 'city_name': 'Blantyre', ...            0
# 3  [{'city_name': 'Nonthaburi', 'country_code': '...            3
# 4  [{'acronym': 'NIPD', 'city_name': 'Shanghai', ...           13

# %% [markdown]
# # Publications

# %% [markdown]
# Let's start querying to do some exploratory data analysis on research done at UCSD.

# %%
# set some variables here to make it easier to query
GRIDID = "grid.266100.3" # Grid ID for University of California, San Diego
FIELDS = "title+type+year+journal+authors+research_orgs+research_org_names+publisher+times_cited+funders"

# %%
query = f"""search publications in title_abstract_only
            for "artificial intelligence" 
            where research_orgs.id="{GRIDID}" 
            return publications[{FIELDS}] sort by year limit 645"""
result = dsl.query(query)
# Out:
# Returned Publications: 645 (total = 651)
# Time: 2.01s
# WARNINGS [1]
# Field current_organization_id of the authors field is deprecated and will be removed in the next major release.

# %%
# turn result from Dimcli query into pandas dataframe
pubs = result.as_dataframe()
pubs.head()
# Out:
#                                                title  \
# 0  Driving towards digital biomanufacturing by CH...
# 1  Artificial Intelligence (AI) for Early Diagnos...
# 2  Artificial Intelligence–Generated Draft Replie...
# 3  Novel Technologies in Artificial Intelligence ...
# 4  Observing Schrödinger’s cat with artificial in...
#
#                                              authors  \
# 0  [{'affiliations': [{'city': 'Seoul', 'city_id'...
# 1  [{'affiliations': [{'city': 'Chandigarh', 'cit...
# 2  [{'affiliations': [{'city': 'Stanford', 'city_...
# 3  [{'affiliations': [{'city': None, 'city_id': N...
# 4  [{'affiliations': [{'city': 'Beijing', 'city_i...
#
#                                              funders  \
# 0  [{'acronym': 'MSIT', 'city_name': 'Anyang-si',...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                             publisher  \
# 0                            Elsevier
# 1                                MDPI
# 2  American Medical Association (AMA)
# 3                      Wolters Kluwer
# 4                      IOP Publishing
#
#                                   research_org_names  \
# 0  [Sartorius Corporate Research, Avenue Ariane 5...
# 1  [Sapienza University of Rome, University of Be...
# 2  [Stanford University, Stanford Medicine, Unive...
# 3  [Viterbi Family Department of Ophthalmology, H...
# 4  [Peking University, Harvard University, Univer...
#
#                                        research_orgs  times_cited     type  \
# 0  [{'acronym': 'SKKU', 'city_name': 'Seoul', 'co...            0  article
# 1  [{'acronym': 'UNIBEN', 'city_name': 'Benin Cit...            0  article
# 2  [{'city_name': 'Stanford', 'country_code': 'US...            0  article
# 3  [{'acronym': 'UCSD', 'city_name': 'San Diego',...            0  article
# 4  [{'acronym': 'PKU', 'city_name': 'Beijing', 'c...            0  article
#
#    year    journal.id                             journal.title
# 0  2024  jour.1094293                   Trends in Biotechnology
# 1  2024  jour.1371496                                  Medicina
# 2  2024  jour.1321825                         JAMA Network Open
# 3  2024  jour.1103190                       Journal of Glaucoma
# 4  2024  jour.1381323  Machine Learning: Science and Technology

# %%
ls = pubs.loc[1]['research_org_names']

# %% [markdown]
# ## Data Cleaning and Reformatting

# %% [markdown]
# After querying from Dimensions, let's organize our data so it is easier to work with.

# %%
# let's do some data processing and reformat the data
# the funders information is given a list of dictionaries, each dictionary represents the info for a funder
pubs['funder_name'] = pubs['funders'].apply(lambda x : [] if isinstance(x, float)
                                            else [dict['name'] for dict in x])

# %% [markdown]
# ## Publishers

# %%
# create dataframe to create an order to sort visualization of publishers
count_publisher = pubs['publisher'].value_counts().reset_index()
# count_publisher = count_publisher[count_publisher['publisher'] > 4] # don't include publishers with <4 UCSD publications
count_publisher.head()
# Out:
#                                                index  publisher
# 0                                    Springer Nature        184
# 1                                           Elsevier        117
# 2  Institute of Electrical and Electronics Engine...         66
# 3                                              Wiley         21
# 4          Association for Computing Machinery (ACM)         20

# %% [markdown]
# After pulling publications from University of California, San Diego which are about artificial intelligence, let's visualize which journals people are publishing in and which publishers.

# %%
plt.pie(count_publisher['publisher'], labels=count_publisher['index'])
plt.show()

# %%
sns.barplot(count_publisher, x="publisher", y="index", order=count_publisher['index'])
plt.xlabel('Publication Count')
plt.ylabel('Publisher')
plt.show()

# %% [markdown]
# Which publishers does UCSD have contracts with?...

# %% [markdown]
# What topics do the publications write about? Let's get an overview with a word-cloud visualization.

# %%
# https://api-lab.dimensions.ai/cookbooks/2-publications/Simple-topic-analysis.html

# %% [markdown]
# # Datasets

# %% [markdown]
# At UCSD, where are people publishing datasets?

# %%
#%dsldf search datasets for "machine learning" return datasets

# %% [markdown]
# # Affliations and Collaborations

# %% [markdown]
# In this section, we want to build a network of affliations and collaborations between researchers. We want to look if there are common collaborations cross-university, with implications of building more formal collabortions based on who tends to work together.

# %%
ls
# Out:
# ['Sapienza University of Rome',
#  'University of Benin',
#  'University of Catania',
#  'University of California, San Diego',
#  'Harvard University',
#  'Policlinico Umberto I',
#  'Università degli Studi di Enna Kore',
#  'Università Campus Bio-Medico',
#  'Government Medical College and Hospital',
#  'Campus Bio Medico University Hospital',
#  'Ospedale Santa Maria della Misericordia di Udine']

# %%
# each node is a university. each edge represents number of publications that they have collaborated on 
G = nx.Graph()

# %%
# add nodes. takes in a list of universities
def addNodeEdges(ls):
    if 'University of California, San Diego' not in ls:
        print('False')

    for uni in ls: 
        # if uni is UCSD, continue
        # if uni not in graph, add and add edge between UCSD and uni
        # else, increase edge weight of UCSD, uni 
        if uni == 'University of California, San Diego':
            continue

        if uni in G.nodes:
            curr_weight = G.edges[uni, 'University of California, San Diego']['weight']
            G.edges[uni, 'University of California, San Diego']['weight'] = curr_weight + 1
        else:
            G.add_node(uni)
            G.add_edge(uni, 'University of California, San Diego', weight=1)

# %%
pubs['research_org_names'].apply(addNodeEdges)
# Out:
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 640    None
# 641    None
# 642    None
# 643    None
# 644    None
# Name: research_org_names, Length: 645, dtype: object

# %%
# plot the network of collaborations 
nx.draw_networkx(G, font_size=3)

# add edge labels
pos = nx.spring_layout(G, seed=7)  # positions for all nodes - seed for reproducibility
edge_labels = nx.get_edge_attributes(G, "weight")
nx.draw_networkx_edge_labels(G, pos, edge_labels, font_size=3)

plt.axis("off")
plt.show()

# %%
query_template = """
    search publications
       where
        research_orgs.id = "{}"
        and research_orgs.id in {}
        and year in [{}:{}]
    return publications[id+doi+type+times_cited+year+authors]
    """

# %%
# normal query
res = dsl.query("search publications for \"artificial-intelligence\" return researchers") # return DslDataset object
[x['first_name'] + " " + x['last_name'] for x in res['researchers']]
